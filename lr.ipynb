# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt

# %%
data = {
    "Distance": [2, 3, 4, 5, 6],
    "Delivery_Time": [20, 30, 35, 45, 50]
}

# %%
df = pd.DataFrame(data)

# %%
print("Dataset:")
print(df)
# Out:
# Dataset:
#    Distance  Delivery_Time
# 0         2             20
# 1         3             30
# 2         4             35
# 3         5             45
# 4         6             50

# %%
x = df[["Distance"]]
y = df["Delivery_Time"]

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
print("\nIntercept (b0):", model.intercept_)
print("Slope (b1):", model.coef_[0])
# Out:
# Intercept (b0): 5.9999999999999964
# Slope (b1): 7.500000000000001

# %%
new_distance = [[4]]
prediction = model.predict(new_distance)
# Out:
# /home/parinithaa/project/internship  aiml/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("\nPredicted Delivery Time for 4 km:", prediction[0], "minutes")
# Out:
# Predicted Delivery Time for 4 km: 36.0 minutes

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y, label="Actual Data")
plt.plot(X, y_pred, label="Regression Line")
plt.xlabel("Distance (km)")
plt.ylabel("Delivery Time (minutes)")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()
